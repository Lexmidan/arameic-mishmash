# %%
import numpy as np
# %matplotlib ipympl
import matplotlib.pyplot as plt
import matplotlib as mpl
import sys
import pandas as pd
sys.path.append('C:/Users/aleks/Projects/arameic-mishmash')  
import scipy.constants as c
import scienceplots
plt.style.use('science')

# %%
first=pd.read_csv('Data/data.txt', delimiter='	', decimal=',', names=['t', 'Pa'])
second=pd.read_csv('Data/data_2.txt', delimiter='	', decimal=',', names=['t', 'Pa'])
second.head()
# Out:
#      t       Pa
# 0  0.0  99400.0
# 1  1.0  99400.0
# 2  2.0  99400.0
# 3  3.0  99400.0
# 4  4.0  99400.0

# %%
figuresize=5
import matplotlib.font_manager as fm
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['axes.linewidth'] = 0.7

# %%
fig, axs = plt.subplots(1, 1, figsize=(figuresize+5, figuresize))
axs.plot(first['t'], first['Pa'],'-.', label="Neúspěšný pokus", lw=1.4)
axs.plot(second['t'], second['Pa'],'r-.', label="Úspěšný pokus", lw=1.4)
axs.set_xlabel('Čas [s]',fontsize=18)
axs.set_ylabel('Tlak [Pa]',fontsize=18)
axs.set_yscale('log')
axs.spines['top'].set_visible(False)
axs.spines['right'].set_visible(False)
#axs.grid(color='grey', linestyle='-.', linewidth=0.3, which="both")
axs.tick_params(axis='x',which='both',bottom=True,top=False,labelbottom=True, labelsize=15, size=5)
axs.tick_params(axis='y',which='both',left=True,right=False, labelsize=15, size=5)
axs.legend(loc='upper right')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Ukol 2**

# %%
uk2=pd.read_csv('Data/uk2.asc', delimiter='	', decimal=',', header=0)

# %%
fig, axs1 = plt.subplots(1, 1, figsize=(figuresize+5, figuresize))

axs1.plot(uk2['Mass'],  uk2['Value']*1e5)
axs1.fill_between(uk2['Mass'], uk2['Value']*1e5,color= "b",alpha= 0.2)

axs1.set_xlabel('$\mu$ [g/mol]',fontsize=18)
axs1.set_ylabel('Intenzita signálu',fontsize=18)
axs1.spines['top'].set_visible(False)
axs1.spines['right'].set_visible(False)
#axs.grid(color='grey', linestyle='-.', linewidth=0.3, which="both")
axs1.tick_params(axis='x',which='both',bottom=True,top=False,labelbottom=True, labelsize=15)
axs1.tick_params(axis='y',which='both',left=True,right=False, labelsize=15)
a=-2
axs1.scatter(1.14,1.974)
axs1.text(1.14+a/2,1.974, '$\mathrm{H^+}$')
axs1.scatter(2.1,1.884)
axs1.text(2.1+1,1.884, '$\mathrm{H_2}$')
axs1.scatter(17.8,17.8)
axs1.text(17.8+a,17.8, '$\mathrm{H_2 O}$')
axs1.scatter(15.8,0.7)
axs1.text(15.8+a,0.7, '$\mathrm{O^+}$?')
axs1.scatter(16.8,4.72)
axs1.text(16.8+a,4.72, 'OH')
axs1.scatter(18.8,0.3)
axs1.text(18.8,0.3+0.3, '$\mathrm{DHO}$?')
axs1.scatter(27.8,0.578)
axs1.text(27.8+0.4,0.578, '$\mathrm{N_2}$')
axs1.scatter(43.76,0.2)
axs1.text(43.76-2,0.2, '$\mathrm{CO_2}$')
# Out:
# Text(41.76, 0.2, '$\\mathrm{CO_2}$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **3. úloha**

# %%
uk3=pd.read_csv('Data/uk3_good.asc', delimiter='	', decimal=',', header=None)
uk3_vyp_hrati=pd.read_csv('Data/uk3_vyp_hrati.asc', delimiter='	', decimal=',', header=None)
uk3_vyp_chlaz=pd.read_csv('Data/uk3_vyp_chlaz.asc', delimiter='	', decimal=',', header=None)
#uk3_vyp_hrati[[0,2,4,6,8,10,12]]+=275
#uk3_vyp_chlaz[[0,2,4,6,8,10,12]]+=280+275

#Time[s]	Hydrogen	Time[s]	Water	Time[s]	Nitrogen	Time[s]	Oxygen	Time[s]	Argon	Time[s]	Carbon Dioxide	Time[s]	Helium
uk3_vyp=pd.concat([uk3,uk3_vyp_hrati,uk3_vyp_chlaz],axis=0 )
uk3_vyp.head()
# Out:
#        0         1       2         3       4         5       6             7   \
# 0  46.236  0.000011  46.627  0.000245  47.358  0.000004  47.748  5.973496e-07
# 1  51.133  0.000011  51.534  0.000238  52.245  0.000004  52.635  5.863286e-07
# 2  56.010  0.000010  56.411  0.000232  57.132  0.000004  57.533  5.773566e-07
# 3  60.867  0.000010  61.268  0.000227  61.979  0.000004  62.369  5.713755e-07
# 4  65.734  0.000010  66.125  0.000223  66.826  0.000004  67.206  5.657339e-07
#
#        8             9       10        11      12   13
# 0  48.469  1.159944e-07  44.303  0.000002  44.694  0.0
# 1  53.367  1.082045e-07  49.191  0.000002  49.571  0.0
# 2  58.234  1.012445e-07  54.068  0.000002  54.789  0.0
# 3  63.111  9.549067e-08  58.955  0.000001  59.666  0.0
# 4  67.937  9.159177e-08  63.822  0.000001  64.533  0.0

# %%
fig, axs2 = plt.subplots(1, 3, figsize=(figuresize+5, figuresize), sharey=True)

axs2[0].scatter(uk3[0],uk3[1],  label='Hydrogen', marker='+', s=20)
axs2[0].scatter(uk3[2],uk3[3],  label='Water', marker='+', s=20)
axs2[0].scatter(uk3[4],uk3[5],  label='Nitrogen', marker='+', s=20)
axs2[0].scatter(uk3[6],uk3[7],  label='Oxygen', marker='+', s=20)
axs2[0].scatter(uk3[8],uk3[9],  label='Carbon Dioxide', marker='+', s=20)
axs2[0].scatter(uk3[10],uk3[11],  label='Argon', marker='+', s=20)
axs2[0].scatter(uk3[12],uk3[13],  label='Helium', marker='+', s=20)
axs2[0].set_yscale('log')


axs2[0].set_ylabel('Parciální tlak [Pa]',fontsize=18)
axs2[0].spines['top'].set_visible(False)
axs2[0].spines['right'].set_visible(False)
#axs.grid(color='grey', linestyle='-.', linewidth=0.3, which="both")
axs2[0].tick_params(axis='x',which='both',bottom=True,top=False,labelbottom=True, labelsize=15, size=5)
axs2[0].tick_params(axis='y',which='both',left=True,right=False, labelsize=15, size=5)



axs2[1].scatter(uk3_vyp_hrati[0],uk3_vyp_hrati[1],  label='Hydrogen', marker='+', s=20)
axs2[1].scatter(uk3_vyp_hrati[2],uk3_vyp_hrati[3],  label='Water', marker='+', s=20)
axs2[1].scatter(uk3_vyp_hrati[4],uk3_vyp_hrati[5],  label='Nitrogen', marker='+', s=20)
axs2[1].scatter(uk3_vyp_hrati[6],uk3_vyp_hrati[7],  label='Oxygen', marker='+', s=20)
axs2[1].scatter(uk3_vyp_hrati[8],uk3_vyp_hrati[9],  label='Carbon Dioxide', marker='+', s=20)
axs2[1].scatter(uk3_vyp_hrati[10],uk3_vyp_hrati[11],  label='Argon', marker='+', s=20)
axs2[1].scatter(uk3_vyp_hrati[12],uk3_vyp_hrati[13],  label='Helium', marker='+', s=20)

axs2[1].set_yscale('log')

axs2[1].set_xlabel('Čas [s]',fontsize=18)

axs2[1].tick_params(axis='x',which='both',bottom=True,top=False,labelbottom=True, labelsize=15, size=5)
axs2[1].tick_params(axis='y',which='both',left=True,right=False, labelsize=15, size=5)
axs2[1].spines['top'].set_visible(False)
axs2[1].spines['right'].set_visible(False)
#axs2[1].spines['left'].set_visible(False)

axs2[2].scatter(uk3_vyp_chlaz[0],uk3_vyp_chlaz[1],  label='Hydrogen', marker='+', s=20)
axs2[2].scatter(uk3_vyp_chlaz[2],uk3_vyp_chlaz[3],  label='Water', marker='+', s=20)
axs2[2].scatter(uk3_vyp_chlaz[4],uk3_vyp_chlaz[5],  label='Nitrogen', marker='+', s=20)
axs2[2].scatter(uk3_vyp_chlaz[6],uk3_vyp_chlaz[7],  label='Oxygen', marker='+', s=20)
axs2[2].scatter(uk3_vyp_chlaz[8],uk3_vyp_chlaz[9],  label='Carbon Dioxide', marker='+', s=20)
axs2[2].scatter(uk3_vyp_chlaz[10],uk3_vyp_chlaz[11],  label='Argon', marker='+', s=20)
axs2[2].scatter(uk3_vyp_chlaz[12],uk3_vyp_chlaz[13],  label='Helium', marker='+', s=20)
axs2[2].tick_params(axis='x',which='both',bottom=True,top=False,labelbottom=True, labelsize=15, size=5)
axs2[2].tick_params(axis='y',which='both',left=True,right=False, labelsize=15, size=5)
axs2[2].spines['top'].set_visible(False)
axs2[2].spines['right'].set_visible(False)
#axs2[2].spines['left'].set_visible(False)
axs2[2].set_yscale('log')


axs2[2].legend(loc='upper center', bbox_to_anchor=(0.8, 1.1),
          ncol=2, fancybox=True, shadow=True)

axs2[2].spines['top'].set_visible(False)
axs2[2].spines['right'].set_visible(False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **4 ukol**

# %%
uk4=pd.read_csv('Data/uk4.asc', delimiter='	', decimal=',', header=None)

# %%
fig, axs3 = plt.subplots(1, 1, figsize=(figuresize+5, figuresize))

axs3.scatter(uk4[0],uk4[1],  label='Hydrogen', marker='+', s=20)
axs3.scatter(uk4[2],uk4[3],  label='Water', marker='+', s=20)
axs3.scatter(uk4[4],uk4[5],  label='Nitrogen', marker='+', s=20)
axs3.scatter(uk4[6],uk4[7],  label='Oxygen', marker='+', s=20)
axs3.scatter(uk4[8],uk4[9],  label='Carbon Dioxide', marker='+', s=20)
axs3.scatter(uk4[10],uk4[11],  label='Argon', marker='+', s=20)
axs3.scatter(uk4[12],uk4[13],  label='Helium', c='magenta', marker='D', s=25)
axs3.set_yscale('log')
axs3.set_xlabel('Čas [s]',fontsize=18)
axs3.set_ylabel('Parciální tlak [Pa]',fontsize=18)
axs3.spines['top'].set_visible(False)
axs3.spines['right'].set_visible(False)
axs3.grid(color='grey', linestyle='-.', linewidth=0.3, which="both")
axs3.tick_params(axis='x',which='both',bottom=True,top=False,labelbottom=True, labelsize=15, size=5)
axs3.tick_params(axis='y',which='both',left=True,right=False, labelsize=15, size=5)
axs3.legend(loc='upper center', bbox_to_anchor=(0.5, 0.25),ncol=3, fancybox=True, shadow=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
uk5_1=pd.read_csv('Data/uk5_1.asc', delimiter='	', decimal=',', header=None)
uk5_2=pd.read_csv('Data/uk5_2.asc', delimiter='	', decimal=',', header=None)
# uk5_2[[0,2,4,6,8,10,12]]+=290
uk5=pd.concat([uk5_1, uk5_2], axis=0)
uk5
# Out:
#          0         1        2         3        4         5        6   \
# 0     3.367  0.000002    3.758  0.000042    4.489  0.000005    0.333
# 1     8.214  0.000002    8.604  0.000042    9.326  0.000005    5.190
# 2    13.421  0.000002   13.802  0.000042   14.513  0.000005   10.037
# 3    18.288  0.000002   18.669  0.000042   19.390  0.000005   15.224
# 4    23.145  0.000002   23.536  0.000042   24.257  0.000005   20.111
# ..      ...       ...      ...       ...      ...       ...      ...
# 53  256.621  0.000002  257.032  0.000036  257.753  0.000005  258.454
# 54  261.508  0.000002  261.899  0.000035  262.630  0.000005  263.341
# 55  266.345  0.000002  266.756  0.000035  267.477  0.000005  268.198
# 56  271.252  0.000002  271.643  0.000035  272.364  0.000005  272.754
# 57  276.059  0.000002  276.450  0.000035  277.171  0.000005  277.882
#
#               7        8             9        10            11       12  \
# ...

# %%
fig2, axs4 = plt.subplots(1, 2, figsize=(figuresize+5, figuresize), sharey=True)
axs4[0].scatter(uk5_1[0],uk5_1[1],  label='$\mathrm{H_2}$', marker='+', s=20)
axs4[0].scatter(uk5_1[2],uk5_1[3],  label='$\mathrm{H_2 O}$', marker='+', s=20)
axs4[0].scatter(uk5_1[4],uk5_1[5],  label='$\mathrm{N_2}$', marker='+', s=20)
axs4[0].scatter(uk5_1[6],uk5_1[7],  label='$\mathrm{O_2}$', marker='+', s=20)
axs4[0].scatter(uk5_1[8],uk5_1[9],  label='$\mathrm{CO_2}$', marker='+', s=20)
axs4[0].scatter(uk5_1[10],uk5_1[11],  label='$\mathrm{Ar}$', marker='+', s=20)
axs4[0].scatter(uk5_1[12],uk5_1[13],  label='$\mathrm{He}$', c='magenta', marker='+', s=20)

axs4[0].set_yscale('log')

axs4[0].set_ylabel('Parciální tlak [Pa]',fontsize=18)
axs4[0].spines['top'].set_visible(False)
axs4[0].spines['right'].set_visible(False)
#axs4[0].grid(color='grey', linestyle='-.', linewidth=0.3, which="both")
axs4[0].tick_params(axis='x',which='both',bottom=True,top=False,labelbottom=True, labelsize=15, size=5)
axs4[0].tick_params(axis='y',which='both',left=True,right=False, labelsize=15, size=5)
#axs4[0].legend(loc='upper right', bbox_to_anchor=(1.2, 1),ncol=2, fancybox=True, shadow=True)

axs4[1].scatter(uk5_2[0],uk5_2[1],  label='Hydrogen', marker='+', s=20)
axs4[1].scatter(uk5_2[2],uk5_2[3],  label='Water', marker='+', s=20)
axs4[1].scatter(uk5_2[4],uk5_2[5],  label='Nitrogen', marker='+', s=20)
axs4[1].scatter(uk5_2[6],uk5_2[7],  label='Oxygen', marker='+', s=20)
axs4[1].scatter(uk5_2[8],uk5_2[9],  label='Carbon Dioxide', marker='+', s=20)
axs4[1].scatter(uk5_2[10],uk5_2[11],  label='Argon', marker='+', s=20)
axs4[1].scatter(uk5_2[12],uk5_2[13],  label='Helium', c='magenta', marker='+', s=20)
axs4[1].legend(loc='upper right', bbox_to_anchor=(1.3, 1),ncol=2, fancybox=True, shadow=True)
axs4[1].set_yscale('log')

axs4[1].spines['top'].set_visible(False)
axs4[1].spines['right'].set_visible(False)
#axs4[1].grid(color='grey', linestyle='-.', linewidth=0.3, which="both")
axs4[1].tick_params(axis='x',which='both',bottom=True,top=False,labelbottom=True, labelsize=15, size=5)
axs4[1].tick_params(axis='y',which='both',left=True,right=False, labelsize=15, size=5)
fig2.text(0.48, 0.04, 'Čas [s]',fontsize=18)
# Out:
# Text(0.48, 0.04, 'Čas [s]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
